# %%
import numpy as np
import pandas as pd
import seaborn  as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Contar duplicados

# %%
data = pd.read_csv("DATA_PF_IV.csv")

# %%
data.columns
# Out:
# Index(['Time', 'Country Name', 'Country Code',
#        'Birth rate, crude (per 1,000 people)',
#        'Death rate, crude (per 1,000 people)',
#        'Fertility rate, total (births per woman)',
#        'Life expectancy at birth, female (years)',
#        'Life expectancy at birth, male (years)',
#        'Life expectancy at birth, total (years)',
#        'Mortality rate, adult, female (per 1,000 female adults)',
#        'Mortality rate, adult, male (per 1,000 male adults)',
#        'Mortality rate, infant (per 1,000 live births)',
#        'Mortality rate, infant, female (per 1,000 live births)',
#        'Mortality rate, infant, male (per 1,000 live births)',
#        'Mortality rate, neonatal (per 1,000 live births)',
#        'Population growth (annual %)', 'Number of infant deaths',
#        'Number of neonatal deaths', 'Net migration', 'Population, female',
#        'Population, female (% of total population)', 'Population, male',
#        'Population, male (% of total population)', 'Population, total',
#        'Rural population', 'Rural population (% of total population)',
#        'Rural population growth (annual %)', 'Urban population',
#        'Urban population (% of total population)',
#        'Urban population growth (annual %)',
#        'Sex ratio at birth (male births per female births)',
#        'Adolescent fertility rate (births per 1,000 women ages 15-19)',
#        'GDP (current US$)', 'GDP growth (annual %)',
#        'Immunization, DPT (% of children ages 12-23 months)',
#        'Immunization, measles (% of children ages 12-23 months)',
#        'Esperanza de vida saludable, total',
#        'Esperanza de vida saludable, hombres',
#        'Esperanza de vida saludable, mujeres'],
#       dtype='object')

# %%
data.shape
# Out:
# (1368, 39)

# %%
data.sample(3)
# Out:
#       Time Country Name Country Code  Birth rate, crude (per 1,000 people)
# 839   1998    Nicaragua          NIC                                  29.0  \
# 1274  2001      Uruguay          URY                                  15.5
# 432   1987         Fiji          FJI                                  30.7
#
#       Death rate, crude (per 1,000 people)
# 839                                    6.3  \
# 1274                                   9.1
# 432                                    6.4
#
#       Fertility rate, total (births per woman)
# 839                                        3.3  \
# 1274                                       2.1
# 432                                        3.5
#
#       Life expectancy at birth, female (years)
# 839                                       67.7  \
# 1274                                      79.8
# 432                                       67.8
#
#       Life expectancy at birth, male (years)
# 839                                     62.7  \
# 1274                                    70.8
# 432                                     62.6
#
#       Life expectancy at birth, total (years)
# 839                                      65.2  \
# 1274                                     75.3
# 432                                      64.9
#
#       Mortality rate, adult, female (per 1,000 female adults)  ...
# 839                                               180.7        ...  \
# 1274                                               88.1        ...
# 432                                               206.6        ...
#
#       Urban population growth (annual %)
# 839                                  1.9  \
# 1274                                 0.6
# 432                                  3.3
#
#       Sex ratio at birth (male births per female births)
# 839                                                 1.0   \
# 1274                                                1.1
# 432                                                 1.1
#
#       Adolescent fertility rate (births per 1,000 women ages 15-19)
# 839                                               117.6              \
# 1274                                               70.8
# 432                                                77.4
#
#       GDP (current US$)  GDP growth (annual %)
# 839        4.635267e+09                    3.7  \
# 1274       2.089879e+10                   -3.8
# 432        1.177908e+09                   -6.6
#
#       Immunization, DPT (% of children ages 12-23 months)
# 839                                                73.0    \
# 1274                                               94.0
# 432                                                90.0
#
#       Immunization, measles (% of children ages 12-23 months)
# 839                                                91.0        \
# 1274                                               94.0
# 432                                                64.0
#
#       Esperanza de vida saludable, total
# 839                                 61.4  \
# 1274                                65.7
# 432                                  NaN
#
#       Esperanza de vida saludable, hombres
# 839                                   59.8  \
# 1274                                  63.5
# 432                                    NaN
#
#       Esperanza de vida saludable, mujeres
# 839                                   63.1
# 1274                                  67.9
# 432                                    NaN
#
# [3 rows x 39 columns]

# %%
data.nunique()
# Out:
# Time                                                               36
# Country Name                                                       38
# Country Code                                                       38
# Birth rate, crude (per 1,000 people)                              299
# Death rate, crude (per 1,000 people)                               92
# Fertility rate, total (births per woman)                           51
# Life expectancy at birth, female (years)                          255
# Life expectancy at birth, male (years)                            268
# Life expectancy at birth, total (years)                           265
# Mortality rate, adult, female (per 1,000 female adults)           976
# Mortality rate, adult, male (per 1,000 male adults)              1057
# Mortality rate, infant (per 1,000 live births)                    497
# Mortality rate, infant, female (per 1,000 live births)            458
# Mortality rate, infant, male (per 1,000 live births)              547
# Mortality rate, neonatal (per 1,000 live births)                  313
# Population growth (annual %)                                       63
# Number of infant deaths                                          1052
# Number of neonatal deaths                                         967
# Net migration                                                    1276
# Population, female                                               1360
# Population, female (% of total population)                         68
# Population, male                                                 1363
# Population, male (% of total population)                           69
# Population, total                                                1366
# Rural population                                                 1332
# Rural population (% of total population)                          620
# Rural population growth (annual %)                                 86
# Urban population                                                 1364
# Urban population (% of total population)                          620
# Urban population growth (annual %)                                 86
# Sex ratio at birth (male births per female births)                  2
# Adolescent fertility rate (births per 1,000 women ages 15-19)     722
# GDP (current US$)                                                1283
# GDP growth (annual %)                                             220
# Immunization, DPT (% of children ages 12-23 months)                66
# Immunization, measles (% of children ages 12-23 months)            73
# Esperanza de vida saludable, total                                176
# Esperanza de vida saludable, hombres                              171
# Esperanza de vida saludable, mujeres                              170
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1368 entries, 0 to 1367
# Data columns (total 39 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Time                                                           1368 non-null   int64
#  1   Country Name                                                   1368 non-null   object
#  2   Country Code                                                   1368 non-null   object
#  3   Birth rate, crude (per 1,000 people)                           1327 non-null   float64
#  4   Death rate, crude (per 1,000 people)                           1327 non-null   float64
#  5   Fertility rate, total (births per woman)                       1302 non-null   float64
#  6   Life expectancy at birth, female (years)                       1299 non-null   float64
#  7   Life expectancy at birth, male (years)                         1299 non-null   float64
#  8   Life expectancy at birth, total (years)                        1299 non-null   float64
#  9   Mortality rate, adult, female (per 1,000 female adults)        1292 non-null   float64
#  10  Mortality rate, adult, male (per 1,000 male adults)            1292 non-null   float64
#  11  Mortality rate, infant (per 1,000 live births)                 1330 non-null   float64
#  12  Mortality rate, infant, female (per 1,000 live births)         1330 non-null   float64
#  13  Mortality rate, infant, male (per 1,000 live births)           1330 non-null   float64
#  14  Mortality rate, neonatal (per 1,000 live births)               1304 non-null   float64
#  15  Population growth (annual %)                                   1329 non-null   float64
#  16  Number of infant deaths                                        1330 non-null   float64
#  17  Number of neonatal deaths                                      1291 non-null   float64
#  18  Net migration                                                  1368 non-null   float64
#  19  Population, female                                             1368 non-null   float64
#  20  Population, female (% of total population)                     1368 non-null   float64
#  21  Population, male                                               1368 non-null   float64
#  22  Population, male (% of total population)                       1368 non-null   float64
#  23  Population, total                                              1368 non-null   float64
#  24  Rural population                                               1368 non-null   float64
#  25  Rural population (% of total population)                       1368 non-null   float64
#  26  Rural population growth (annual %)                             1295 non-null   float64
#  27  Urban population                                               1368 non-null   float64
#  28  Urban population (% of total population)                       1368 non-null   float64
#  29  Urban population growth (annual %)                             1330 non-null   float64
#  30  Sex ratio at birth (male births per female births)             1330 non-null   float64
#  31  Adolescent fertility rate (births per 1,000 women ages 15-19)  1292 non-null   float64
#  32  GDP (current US$)                                              1283 non-null   float64
#  33  GDP growth (annual %)                                          1276 non-null   float64
#  34  Immunization, DPT (% of children ages 12-23 months)            1329 non-null   float64
#  35  Immunization, measles (% of children ages 12-23 months)        1320 non-null   float64
#  36  Esperanza de vida saludable, total                             720 non-null    float64
#  37  Esperanza de vida saludable, hombres                           720 non-null    float64
#  38  Esperanza de vida saludable, mujeres                           720 non-null    float64
# dtypes: float64(36), int64(1), object(2)
# memory usage: 416.9+ KB

# %%
data.loc[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Time, Country Name, Country Code, Birth rate, crude (per 1,000 people), Death rate, crude (per 1,000 people), Fertility rate, total (births per woman), Life expectancy at birth, female (years), Life expectancy at birth, male (years), Life expectancy at birth, total (years), Mortality rate, adult, female (per 1,000 female adults), Mortality rate, adult, male (per 1,000 male adults), Mortality rate, infant (per 1,000 live births), Mortality rate, infant, female (per 1,000 live births), Mortality rate, infant, male (per 1,000 live births), Mortality rate, neonatal (per 1,000 live births), Population growth (annual %), Number of infant deaths, Number of neonatal deaths, Net migration, Population, female, Population, female (% of total population), Population, male, Population, male (% of total population), Population, total, Rural population, Rural population (% of total population), Rural population growth (annual %), Urban population, Urban population (% of total population), Urban population growth (annual %), Sex ratio at birth (male births per female births), Adolescent fertility rate (births per 1,000 women ages 15-19), GDP (current US$), GDP growth (annual %), Immunization, DPT (% of children ages 12-23 months), Immunization, measles (% of children ages 12-23 months), Esperanza de vida saludable, total, Esperanza de vida saludable, hombres, Esperanza de vida saludable, mujeres]
# Index: []
#
# [0 rows x 39 columns]

# %%
data["Time"].value_counts()
# Out:
# Time
# 1987    38
# 1988    38
# 2007    38
# 2008    38
# 2009    38
# 2010    38
# 2011    38
# 2012    38
# 2013    38
# 2014    38
# 2015    38
# 2016    38
# 2017    38
# 2018    38
# 2019    38
# 2020    38
# 2021    38
# 2006    38
# 2005    38
# 2004    38
# 1995    38
# 1989    38
# 1990    38
# 1991    38
# 1992    38
# 1993    38
# 1994    38
# 1996    38
# 2003    38
# 1997    38
# 1998    38
# 1999    38
# 2000    38
# 2001    38
# 2002    38
# 2022    38
# Name: count, dtype: int64

# %%
data["Time"].value_counts() \
    .head() \
    .plot(kind = "bar", title = "Años con mas frecuencia de datos")
# Out:
# <AxesSubplot: title={'center': 'Años con mas frecuencia de datos'}, xlabel='Time'>

# %%
data["Country Name"].value_counts()
# Out:
# Country Name
# Argentina                36
# Papua New Guinea         36
# Nauru                    36
# New Zealand              36
# Nicaragua                36
# Palau                    36
# Panama                   36
# Paraguay                 36
# Peru                     36
# Samoa                    36
# Australia                36
# Solomon Islands          36
# Suriname                 36
# Tonga                    36
# Tuvalu                   36
# United States            36
# Uruguay                  36
# Vanuatu                  36
# Micronesia, Fed. Sts.    36
# Mexico                   36
# Marshall Islands         36
# Kiribati                 36
# Belize                   36
# Bolivia                  36
# Brazil                   36
# Canada                   36
# Chile                    36
# Colombia                 36
# Costa Rica               36
# Cuba                     36
# Ecuador                  36
# El Salvador              36
# Fiji                     36
# Guatemala                36
# Guyana                   36
# Honduras                 36
# Haiti                    36
# Venezuela                36
# Name: count, dtype: int64

# %%
data["Country Name"].value_counts() \
    .head(10) \
    .plot(kind = "barh", title = "Países con mas frecuencia de datos")
# Out:
# <AxesSubplot: title={'center': 'Países con mas frecuencia de datos'}, ylabel='Country Name'>

# %%
columns_names  = data.columns

# %%
duplicates_numbers = data.drop(labels = columns_names, axis =1).duplicated

# %%
data.describe(exclude="number")
# Out:
#        Country Name Country Code
# count          1368         1368
# unique           38           38
# top       Argentina          ARG
# freq             36           36

# %%
data.describe()
# Out:
#               Time  Birth rate, crude (per 1,000 people)
# count  1368.000000                           1327.000000  \
# mean   2004.500000                             24.014846
# std      10.392094                              7.670603
# min    1987.000000                              8.900000
# 25%    1995.750000                             17.700000
# 50%    2004.500000                             23.700000
# 75%    2013.250000                             30.100000
# max    2022.000000                             46.400000
#
#        Death rate, crude (per 1,000 people)
# count                           1327.000000  \
# mean                               6.819668
# std                                1.677739
# min                                3.800000
# 25%                                5.600000
# 50%                                6.700000
# 75%                                7.600000
# max                               17.700000
#
#        Fertility rate, total (births per woman)
# count                               1302.000000  \
# mean                                   3.099770
# std                                    1.061459
# min                                    0.800000
# 25%                                    2.200000
# 50%                                    2.900000
# 75%                                    3.900000
# max                                    6.600000
#
#        Life expectancy at birth, female (years)
# count                               1299.000000  \
# mean                                  73.248884
# std                                    6.005248
# min                                   46.300000
# 25%                                   68.800000
# 50%                                   73.700000
# 75%                                   77.700000
# max                                   85.400000
#
#        Life expectancy at birth, male (years)
# count                             1299.000000  \
# mean                                67.587144
# std                                  5.870891
# min                                 45.800000
# 25%                                 63.400000
# 50%                                 67.600000
# 75%                                 71.700000
# max                                 81.300000
#
#        Life expectancy at birth, total (years)
# count                              1299.000000  \
# mean                                 70.314858
# std                                   5.935566
# min                                  46.000000
# 25%                                  66.000000
# 50%                                  70.500000
# 75%                                  74.600000
# max                                  83.300000
#
#        Mortality rate, adult, female (per 1,000 female adults)
# count                                        1292.000000        \
# mean                                          140.569737
# std                                            62.104884
# min                                            41.700000
# 25%                                            92.275000
# 50%                                           129.900000
# 75%                                           179.825000
# max                                           482.200000
#
#        Mortality rate, adult, male (per 1,000 male adults)
# count                                        1292.000000    \
# mean                                          224.201625
# std                                            81.372402
# min                                            73.000000
# 25%                                           168.225000
# 50%                                           216.800000
# 75%                                           280.725000
# max                                           501.300000
#
#        Mortality rate, infant (per 1,000 live births)  ...
# count                                     1330.000000  ...  \
# mean                                        25.050301  ...
# std                                         16.652338  ...
# min                                          3.200000  ...
# 25%                                         13.400000  ...
# 50%                                         21.750000  ...
# 75%                                         32.200000  ...
# max                                        108.200000  ...
#
#        Urban population growth (annual %)
# count                         1330.000000  \
# mean                             1.909624
# std                              1.378197
# min                             -2.900000
# 25%                              1.100000
# 50%                              1.800000
# 75%                              2.800000
# max                              6.300000
#
#        Sex ratio at birth (male births per female births)
# count                                        1330.000000   \
# mean                                            1.059774
# std                                             0.049054
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             1.100000
# 75%                                             1.100000
# max                                             1.100000
#
#        Adolescent fertility rate (births per 1,000 women ages 15-19)
# count                                        1292.000000              \
# mean                                           67.754257
# std                                            27.802080
# min                                             6.900000
# 25%                                            47.700000
# 50%                                            69.650000
# 75%                                            87.000000
# max                                           150.900000
#
#        GDP (current US$)  GDP growth (annual %)
# count       1.283000e+03            1276.000000  \
# mean        4.861683e+11               2.766301
# std         2.238422e+12               4.566697
# min         8.824448e+06             -22.900000
# 25%         8.213300e+08               0.800000
# 50%         1.261460e+10               3.000000
# 75%         8.608596e+10               5.000000
# max         2.331508e+13              43.500000
#
#        Immunization, DPT (% of children ages 12-23 months)
# count                                        1329.000000    \
# mean                                           83.929270
# std                                            14.072835
# min                                            16.000000
# 25%                                            78.000000
# 50%                                            88.000000
# 75%                                            94.000000
# max                                            99.000000
#
#        Immunization, measles (% of children ages 12-23 months)
# count                                        1320.000000        \
# mean                                           84.227273
# std                                            15.065835
# min                                             8.000000
# 25%                                            78.000000
# 50%                                            90.000000
# 75%                                            95.000000
# max                                            99.000000
#
#        Esperanza de vida saludable, total
# count                          720.000000  \
# mean                            63.779306
# std                              4.523759
# min                             29.000000
# 25%                             62.200000
# 50%                             64.700000
# 75%                             66.600000
# max                             70.800000
#
#        Esperanza de vida saludable, hombres
# count                            720.000000  \
# mean                              62.374306
# std                                4.496269
# min                               26.100000
# 25%                               60.500000
# 50%                               63.050000
# 75%                               65.200000
# max                               70.000000
#
#        Esperanza de vida saludable, mujeres
# count                            720.000000
# mean                              65.240417
# std                                4.670106
# min                               32.400000
# 25%                               63.675000
# 50%                               66.500000
# 75%                               68.200000
# max                               71.400000
#
# [8 rows x 37 columns]

# %%
plt.figure(figsize=(10, 8))
plt.imshow(data.isna(), aspect='auto', interpolation='nearest', cmap='Greys')
plt.xlabel("Número de columnas")
plt.ylabel("Número de muestras")
plt.show()

# %%
data.isna().mean().sort_values().plot(
    kind = "bar", figsize = (15,4),
    title = "Porcentaje de valores faltanres por columna",
    ylabel = "Relación de valores perdidos por columna")
# Out:
# <AxesSubplot: title={'center': 'Porcentaje de valores faltanres por columna'}, ylabel='Relación de valores perdidos por columna'>

# %%
sns.pairplot(data, vars = ["Life expectancy at birth, total (years)", 
                           "Mortality rate, neonatal (per 1,000 live births)",
                           "Mortality rate, infant (per 1,000 live births)"])

# %%
# Crear pairplot
g = sns.pairplot(data, vars=["Life expectancy at birth, total (years)",
                            "Mortality rate, neonatal (per 1,000 live births)",
                            "Mortality rate, infant (per 1,000 live births)"])

# Modificar nombres de los ejes
g.set_axis_labels("Expectativa de vida al nacer", "Tasa de mortalidad neonatal")
g.set(xticklabels=[], yticklabels=[])

# Mostrar el gráfico
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 7
#       2 g = sns.pairplot(data, vars=["Life expectancy at birth, total (years)",
#       3                             "Mortality rate, neonatal (per 1,000 live births)",
#       4                             "Mortality rate, infant (per 1,000 live births)"])
#       6 # Modificar nombres de los ejes
# ----> 7 g.set_axis_labels("Expectativa de vida al nacer", "Tasa de mortalidad neonatal")
#       8 g.set(xticklabels=[], yticklabels=[])
#      10 # Mostrar el gráfico
#
# AttributeError: 'PairGrid' object has no attribute 'set_axis_labels'

# %%
data["Life expectancy at birth, total (years)"].plot(kind = "box")
# Out:
# <AxesSubplot: >

# %%
data["Number of infant deaths"].plot(kind = "box")
# Out:
# <AxesSubplot: >

# %%
data[data["Number of infant deaths"] > 150000][["Time","Country Name","Number of infant deaths"]]
# Out:
#      Time Country Name  Number of infant deaths
# 144  1987       Brazil                 226814.0
# 145  1988       Brazil                 216736.0
# 146  1989       Brazil                 206798.0
# 147  1990       Brazil                 196801.0
# 148  1991       Brazil                 186652.0
# 149  1992       Brazil                 176041.0
# 150  1993       Brazil                 166243.0
# 151  1994       Brazil                 157301.0

# %%
data["Number of neonatal deaths"].plot(kind = "box")
# Out:
# <AxesSubplot: >

# %%
data[data["Number of neonatal deaths"] > 50000][["Time","Country Name","Number of neonatal deaths"]]
# Out:
#      Time Country Name  Number of neonatal deaths
# 144  1987       Brazil                   111043.0
# 145  1988       Brazil                   106296.0
# 146  1989       Brazil                   102123.0
# 147  1990       Brazil                    97629.0
# 148  1991       Brazil                    93591.0
# 149  1992       Brazil                    89203.0
# 150  1993       Brazil                    86367.0
# 151  1994       Brazil                    83492.0
# 152  1995       Brazil                    81370.0
# 153  1996       Brazil                    78543.0
# 154  1997       Brazil                    76045.0
# 155  1998       Brazil                    73422.0
# 156  1999       Brazil                    69985.0
# 157  2000       Brazil                    65623.0
# 158  2001       Brazil                    61248.0
# 159  2002       Brazil                    56597.0
# 160  2003       Brazil                    52055.0
# 684  1987       Mexico                    59087.0
# 685  1988       Mexico                    56748.0
# 686  1989       Mexico                    55215.0
# 687  1990       Mexico                    53637.0
# 688  1991       Mexico                    52437.0
# 689  1992       Mexico                    51220.0

# %%
columns_correlation = data.iloc[:, 2:].columns

# %%
# Función para convertir a numérico o NaN
def convert_to_numeric(value):
    try:
        return pd.to_numeric(value)
    except:
        return np.nan

# Aplicar la función convert_to_numeric a los valores no numéricos
data = data.applymap(convert_to_numeric)

# %%
correlation = data.corr()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Datos de ejemplo
correlation = np.random.rand(50,50)
columns_correlation = [f"Columna {i+1}" for i in range(correlation.shape[1])]

# Crear mapa de calor
sns.heatmap(correlation, xticklabels=columns_correlation, yticklabels=columns_correlation, annot=True)

# Establecer etiquetas de los ejes
plt.xlabel('Columnas')
plt.ylabel('Columnas')

# Mostrar el gráfico
plt.show()

# %%
sns.heatmap(correlation, xticklabels = columns_correlation, yticklabels = columns_correlation, annot = True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# mirrar relplot

# %%
import numpy as np
import matplotlib.pyplot as plt

# Datos de ejemplo
datos = np.random.rand(5, 5)

# Crear mapa de calor
plt.imshow(data, cmap='hot', interpolation='nearest')
plt.colorbar()

# Establecer etiquetas de los ejes
plt.xticks(range(data.shape[1]))
plt.yticks(range(data.shape[0]))

# Mostrar el gráfico
plt.show()
